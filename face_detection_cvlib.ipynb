# %% [markdown]
# <a href="https://colab.research.google.com/github/udayameister/Connectome/blob/main/face_detection_cvlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cvlib

# %%
# !pip install imutils

# %%
import imutils
import cv2
import cvlib as cv
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
# %matplotlib inline

# %%
img = imutils.url_to_image("https://upload.wikimedia.org/wikipedia/en/thumb/7/7d/Lenna_%28test_image%29.png/220px-Lenna_%28test_image%29.png")

# %%
img3 = cv2.imread("face_2.jpeg")

# %%
cv2_imshow(img3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-e6c89a53f8db> in <cell line: 1>()
# ----> 1 cv2_imshow(img3)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
face, conf = cv.detect_face(img2)
print(face)
print(conf)
# Out:
# [[279, 76, 380, 208], [492, 58, 599, 216], [54, 75, 154, 224]]
# [0.99994886, 0.9942063, 0.91690993]

# %%
for f in face:

    (startX,startY) = f[0],f[1]
    (endX,endY) = f[2],f[3]

    cv2.rectangle(img2, (startX,startY), (endX,endY), (0,255,0), 2)

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=660x367 at 0x7F861016AFD0>

# %%
out = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(out)
