# %% [markdown]
# <a href="https://colab.research.google.com/github/udayameister/linux/blob/main/Visualizing%20Megatrawls%20Network%20Matrices%20from%20Human%20Connectome%20Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Fetching the Megatrawls Network matrices#

# %%
# !pip install -U nilearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nilearn
#   Downloading nilearn-0.10.0-py3-none-any.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 110.5 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from nilearn) (1.10.1)
# Collecting nibabel>=3.2.0
#   Downloading nibabel-5.0.1-py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 81.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.9/dist-packages (from nilearn) (1.4.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from nilearn) (1.2.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nilearn) (4.9.2)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.9/dist-packages (from nilearn) (1.22.4)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.9/dist-packages (from nilearn) (2.27.1)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from nilearn) (1.1.1)
# Requirement already satisfied: packaging>=17 in /usr/local/lib/python3.9/dist-packages (from nibabel>=3.2.0->nilearn) (23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from nibabel>=3.2.0->nilearn) (67.6.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->nilearn) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->nilearn) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.25.0->nilearn) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.25.0->nilearn) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.25.0->nilearn) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.25.0->nilearn) (3.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0.0->nilearn) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->nilearn) (1.16.0)
# Installing collected packages: nibabel, nilearn
#   Attempting uninstall: nibabel
#     Found existing installation: nibabel 3.0.2
#     Uninstalling nibabel-3.0.2:
#       Successfully uninstalled nibabel-3.0.2
# Successfully installed nibabel-5.0.1 nilearn-0.10.0

# %%
from nilearn import datasets

netmats = datasets.fetch_megatrawls_netmats(
    dimensionality=300,
    timeseries="eigen_regression",
    matrices="partial_correlation",
)
# Partial correlation matrices array of size (300, 300) are stored in the name
# of 'correlation_matrices'
partial_correlation = netmats.correlation_matrices
# Out:
# Dataset created in /root/nilearn_data/Megatrawls
#
# Downloading data from http://www.nitrc.org/frs/download.php/8037/Megatrawls.tgz ...
#  ...done. (0 seconds, 0 min)
# Extracting data from /root/nilearn_data/Megatrawls/68c41934c6cf43be91dd107f913ffd01/Megatrawls.tgz..... done.

# %%
from nilearn import plotting
display = plotting.plot_matrix(partial_correlation, colorbar=True, title=title)
plotting.show()
